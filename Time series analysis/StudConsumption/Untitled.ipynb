# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
# %run f2forecast.py

# %%
df=pd.read_excel("DAT.xlsx")
df.head()
# Out:
#    t  Потребл.эн   Ставка
# 0  1      13.176  1526.41
# 1  2      15.408  1529.32
# 2  3      19.488  1528.81
# 3  4      19.176  1535.78
# 4  5      19.176  1540.92

# %%
#NewCons = []
#NewStav = []
#flag = 0
#for i in range(len(df["Ставка"])):
    #if (i==flag):
       # NewCons.append(df['Потребл.эн'][i])
        #NewStav.append(df['Ставка'][i])
        #flag += 2
#print(len(NewCons))

# %%
ConsWith = []
Stav = []
for i in range(len(df["Ставка"])):
    ConsWith.append(df['Потребл.эн'][i])
    Stav.append(df['Ставка'][i])
#Cons without holiyday
FirstWeek = ConsWith[0:47];
SecondWeek = ConsWith[95:215];
ThirdWeek = ConsWith[263:383];
FourWeek = ConsWith[431:551];
LastWeek = ConsWith[599:719];
Cons = FirstWeek + SecondWeek + ThirdWeek + FourWeek + LastWeek;
print(Cons)
# Out:
# [13.176, 15.408, 19.488, 19.176, 19.176, 19.968, 20.64, 22.128, 26.328, 21.84, 21.408, 22.248, 23.184, 24.816, 25.536, 28.536, 28.584, 29.88, 22.2, 19.248, 15.264, 14.4, 14.112, 14.4, 13.776, 14.16, 16.104, 18.768, 21.0, 18.648, 19.224, 18.024, 22.944, 23.088, 20.808, 19.032, 19.056, 19.704, 21.888, 22.224, 25.608, 24.72, 22.176, 18.48, 15.912, 15.384, 14.712, 13.224, 13.344, 14.232, 18.312, 18.048, 19.248, 21.072, 21.552, 21.408, 19.728, 17.712, 20.856, 22.128, 27.768, 28.176, 32.76, 33.312, 36.024, 32.4, 29.64, 25.68, 20.592, 18.288, 16.872, 15.912, 16.656, 17.424, 23.184, 21.288, 20.208, 20.16, 17.952, 18.216, 20.304, 20.544, 19.488, 19.992, 19.8, 24.072, 27.72, 30.456, 30.672, 32.544, 27.192, 21.672, 17.784, 15.936, 14.856, 15.48, 14.76, 16.68, 21.432, 17.472, 19.32, 18.12, 21.696, 22.152, 19.44, 18.984, 16.776, 21.12, 18.768, 18.288, 19.104, 26.4, 29.16, 29.28, 22.704, 17.904, 15.888, 14.064, 13.632, 13.032, 13.32, 13.536, 17.208, 18.816, 16.608, 16.08, 17.784, 18.408, 20.64, 19.416, 16.248, 15.216, 18.96, 22.56, 22.848, 26.352, 24.96, 25.56, 22.128, 21.096, 16.608, 14.544, 14.448, 13.392, 13.896, 14.136, 16.896, 17.784, 20.424, 18.312, 17.256, 21.48, 20.136, 20.592, 19.032, 21.072, 18.864, 18.984, 21.336, 22.92, 25.704, 25.392, 22.992, 17.496, 15.504, 13.08, 13.392, 11.424, 11.688, 12.12, 14.52, 16.416, 16.248, 18.192, 18.912, 16.776, 19.824, 20.784, 22.248, 20.952, 16.272, 17.688, 17.496, 22.656, 26.184, 25.464, 23.256, 17.544, 14.592, 13.488, 11.928, 11.76, 11.784, 14.136, 17.184, 17.544, 18.72, 20.424, 20.472, 20.976, 18.456, 21.144, 19.344, 18.264, 21.456, 22.872, 25.416, 24.264, 26.616, 27.048, 24.528, 23.496, 16.128, 14.64, 13.32, 12.576, 13.56, 14.256, 17.328, 17.616, 18.624, 19.608, 20.448, 22.464, 19.152, 19.272, 18.672, 17.424, 17.688, 22.104, 21.888, 23.448, 24.336, 26.952, 26.208, 19.68, 14.928, 12.288, 11.976, 11.808, 11.592, 14.376, 17.664, 16.824, 17.352, 20.184, 20.928, 21.984, 17.736, 17.112, 18.0, 16.824, 18.12, 21.336, 21.264, 23.568, 24.696, 26.304, 23.664, 19.704, 14.472, 13.776, 12.72, 12.672, 12.384, 16.512, 16.224, 16.224, 17.232, 17.592, 21.648, 19.32, 20.04, 18.312, 17.376, 20.208, 19.68, 24.144, 23.256, 21.48, 23.112, 25.968, 22.272, 19.176, 14.784, 13.248, 12.552, 11.856, 12.192, 15.504, 16.416, 15.552, 17.424, 16.656, 17.04, 17.016, 17.64, 16.2, 15.336, 17.208, 19.344, 23.76, 23.664, 23.856, 25.392, 25.056, 20.112, 19.416, 16.44, 14.616, 13.704, 13.632, 12.528, 13.32, 16.416, 15.288, 16.464, 20.328, 20.928, 20.832, 18.192, 19.896, 18.48, 21.384, 21.048, 20.544, 21.72, 28.656, 32.184, 33.264, 24.672, 19.152, 15.576, 13.08, 11.928, 11.184, 11.256, 15.192, 20.832, 17.64, 16.872, 16.152, 16.296, 19.944, 17.928, 15.6, 17.136, 20.16, 21.456, 24.408, 22.176, 26.472, 28.08, 31.488, 23.136, 17.832, 15.144, 12.216, 11.424, 10.776, 10.776, 11.832, 23.136, 18.408, 15.528, 16.584, 17.472, 18.192, 19.272, 20.616, 20.736, 18.072, 20.28, 21.456, 22.776, 26.616, 27.576, 31.176, 28.776, 20.064, 15.936, 13.992, 13.008, 12.84, 13.512, 14.424, 19.368, 21.24, 17.376, 17.448, 19.128, 21.216, 19.8, 18.624, 17.688, 21.624, 21.264, 17.76, 21.168, 20.832, 23.952, 28.632, 22.992, 17.208, 16.56, 13.704, 11.64, 11.664, 11.712, 13.128, 24.12, 19.704, 14.592, 17.496, 18.048, 22.176, 20.424, 18.936, 18.192, 16.848, 19.488, 19.728, 21.024, 18.408, 24.192, 24.12, 22.032, 19.032, 16.176, 12.432, 12.096, 11.304, 11.76, 14.136, 14.904, 15.552, 14.76, 16.008, 17.064, 20.88, 19.776, 18.792, 15.768, 11.352, 16.008, 20.04, 22.2, 22.296, 24.048, 26.688, 20.016, 15.696, 15.336, 12.696, 11.856, 11.28, 11.256, 12.552, 15.576, 14.808, 15.336, 17.136, 19.056, 19.656, 16.872, 18.432, 19.176, 19.152, 18.168, 18.144, 18.144, 17.904, 22.704, 24.072, 21.48, 17.664, 15.0, 12.72, 11.688, 11.184, 11.256, 13.44, 15.408, 15.72, 17.328, 18.72, 16.872, 19.872, 16.968, 18.024, 16.344, 16.176, 15.912, 18.12, 18.696, 20.352, 24.864, 25.704, 22.656, 17.232, 13.776, 13.032, 12.624, 11.496, 11.448, 13.728, 15.168, 16.224, 14.304, 15.744, 16.8, 19.08, 18.96, ...

# %%
plt.plot(Cons)

# %%
plt.plot(ConsWith)

# %%
df['Потребл.эн'].describe()
# Out:
# count    720.000000
# mean      18.694600
# std        4.498866
# min       10.728000
# 25%       15.480000
# 50%       18.372000
# 75%       21.300000
# max       36.024000
# Name: Потребл.эн, dtype: float64

# %%
df['Ставка'].describe()
# Out:
# count     720.000000
# mean     1591.331639
# std        59.613754
# min      1465.100000
# 25%      1541.742500
# 50%      1594.680000
# 75%      1635.797500
# max      1702.300000
# Name: Ставка, dtype: float64

# %%
# декомпозиция 
result_M = seasonal_decompose(df['Потребл.эн'], model='multiplicative', freq=24)

# Построение графика
plt.rcParams.update({'figure.figsize': (10,10)})
result_M.plot().suptitle('Мультипликативная модель')
# Out:
# Text(0.5, 0.98, 'Мультипликативная модель')

# %%
result_M.seasonal
# Out:
# 0      0.668828
# 1      0.746721
# 2      0.902960
# 3      0.889624
# 4      0.907202
#          ...
# 715    1.029766
# 716    0.846447
# 717    0.738724
# 718    0.694609
# 719    0.669943
# Name: seasonal, Length: 720, dtype: float64

# %%
result_M.trend
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 715   NaN
# 716   NaN
# 717   NaN
# 718   NaN
# 719   NaN
# Name: trend, Length: 720, dtype: float64

# %%
# Decompose 
result_A = seasonal_decompose(df['Потребл.эн'], model='additive', freq=24)

# Plot
plt.rcParams.update({'figure.figsize': (10,10)})
result_A.plot().suptitle('Адитивная модель')
# Out:
# Text(0.5, 0.98, 'Адитивная модель')

# %%
result_A.seasonal
# Out:
# 0     -6.183073
# 1     -4.741832
# 2     -1.775142
# 3     -2.053866
# 4     -1.722987
#          ...
# 715    0.552065
# 716   -2.905556
# 717   -4.899659
# 718   -5.723797
# 719   -6.171728
# Name: seasonal, Length: 720, dtype: float64

# %%
result_A.trend
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 715   NaN
# 716   NaN
# 717   NaN
# 718   NaN
# 719   NaN
# Name: trend, Length: 720, dtype: float64

# %%
import pyEX as pticker

# %%
#https://www.machinelearningmastery.ru/implementing-moving-averages-in-python-1ad28e636f9d/
df.columns=['ds','y','z']
rolling_mean = df.y.rolling(window=24).mean()
rolling_mean2 = df.y.rolling(window=120).mean()
plt.plot(df.ds, df.y, label='AMD')
plt.plot(df.ds, rolling_mean, label='AMD 20 Day SMA', color='orange')
plt.plot(df.ds, rolling_mean2, label='AMD 50 Day SMA', color='magenta')
plt.legend(loc='upper left')
plt.show()

# %%
exp1 = df.y.ewm(span=24, adjust=False).mean()
exp2 = df.y.ewm(span=120, adjust=False).mean()
#plt.plot(df.ds, df.y, label='AMD')
#plt.plot(df.ds, exp1, label='AMD 20 Day EMA')
#plt.plot(df.ds, exp2, label='AMD 50 Day EMA')
#plt.legend(loc='upper left')
#plt.show()

# Decompose 
result_A = seasonal_decompose(exp1, model='additive', freq=24)

# Plot
plt.rcParams.update({'figure.figsize': (10,10)})
result_A.plot().suptitle('Адитивная модель')
# Out:
# Text(0.5, 0.98, 'Адитивная модель')

# %%
train=df.y
train.head()
plt.plot(df.ds, exp1)

# %%
test=df.y
test.head()
# Out:
# 0    13.176
# 1    15.408
# 2    19.488
# 3    19.176
# 4    19.176
# Name: y, dtype: float64

# %%
fit1 = ExponentialSmoothing(train, seasonal_periods=24, trend='add', seasonal='add').fit(use_boxcox=True)

# %%
fit1.params
# Out:
# {'smoothing_level': 0.6077478591434772,
#  'smoothing_slope': 2.356109235558747e-10,
#  'smoothing_seasonal': 1.0454034320359021e-09,
#  'damping_slope': nan,
#  'initial_level': 2.665004822299419,
#  'initial_slope': 5.664577155043408e-11,
#  'initial_seasons': array([0.12835888, 0.25466542, 0.46894491, 0.45564118, 0.48041201,
#         0.555644  , 0.61380122, 0.69144992, 0.67253332, 0.65209841,
#         0.607083  , 0.60627517, 0.62962858, 0.71430857, 0.77715353,
#         0.85707029, 0.97722034, 1.0260297 , 0.84935113, 0.62302535,
#         0.40031328, 0.24591429, 0.17353609, 0.13139112]),
#  'use_boxcox': True,
#  'lamda': 0.053373374363524476,
#  'remove_bias': False}

# %%
fit1.fittedvalues
# Out:
# 0      13.514445
# 1      14.850548
# 2      18.262506
# 3      18.783464
# 4      19.427793
#          ...
# 715    15.200778
# 716    13.190424
# 717    12.712757
# 718    12.823897
# 719    12.482139
# Length: 720, dtype: float64

# %%
fit1.forecast(168)
# Out:
# 720    12.360316
# 721    13.799196
# 722    16.609261
# 723    16.420098
# 724    16.773963
#          ...
# 883    18.955888
# 884    15.655057
# 885    13.694600
# 886    12.857828
# 887    12.393129
# Length: 168, dtype: float64

# %%
ax = df.y.plot(figsize=(15,6), color='black', title="Прогноз методом Хольта Винтерса" )
fit1.fittedvalues.plot(ax=ax, style='--', color='red')
#fit1.forecast(168).plot(ax=ax, style='--', color='green')
plt.show()

# %%
metrics(train, fit1.fittedvalues)
# Out:
# Тест на стационарность:
# 	T-статистика = -15.799
# 	P-значение = 0.000
# Критические значения :
# 	1%: -3.4395677423210493 - Данные  стационарны с вероятностью 99% процентов
# 	5%: -2.8656078730509784 - Данные  стационарны с вероятностью 95% процентов
# 	10%: -2.5689362152032573 - Данные  стационарны с вероятностью 90% процентов
# MAD: 1.3451
# MSE: 3.2496
# MAPE: 0.0706
# MPE: -0.0045
# Стандартная ошибка: 1.8027

# %%
# Decompose 
result_A = seasonal_decompose(fit1.fittedvalues, model='additive', freq=24)

# Plot
plt.rcParams.update({'figure.figsize': (10,10)})
result_A.plot().suptitle('Адитивная модель')
# Out:
# Text(0.5, 0.98, 'Адитивная модель')

# %%
plt.rcParams.update({'figure.figsize': (10,3)})
plot_acf(train, lags=24)
plot_pacf(train, lags=24)
plt.show()

# %%
model = auto_arima(train, seasonal=True, m=24, trace=True, suppress_warnings=True, error_action='ignore', stepwise=True,trend="t")
model
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(2,1,2)x(1,0,1,24) [intercept=True]; AIC=3147.134, BIC=3183.757, Time=20.493 seconds
# Fit ARIMA(0,1,0)x(0,0,0,24) [intercept=True]; AIC=3411.603, BIC=3420.759, Time=0.359 seconds
# Fit ARIMA(1,1,0)x(1,0,0,24) [intercept=True]; AIC=3219.315, BIC=3237.626, Time=10.605 seconds
# Fit ARIMA(0,1,1)x(0,0,1,24) [intercept=True]; AIC=3305.862, BIC=3324.173, Time=8.421 seconds
# Fit ARIMA(0,1,0)x(0,0,0,24) [intercept=False]; AIC=3411.603, BIC=3420.759, Time=0.246 seconds
# Fit ARIMA(2,1,2)x(0,0,1,24) [intercept=True]; AIC=3244.414, BIC=3276.459, Time=32.228 seconds
# Fit ARIMA(2,1,2)x(1,0,0,24) [intercept=True]; AIC=3186.514, BIC=3218.559, Time=20.383 seconds
# Fit ARIMA(2,1,2)x(2,0,1,24) [intercept=True]; AIC=3010.106, BIC=3051.306, Time=159.721 seconds
# Fit ARIMA(2,1,2)x(2,0,0,24) [intercept=True]; AIC=3078.682, BIC=3115.305, Time=111.347 seconds
# Fit ARIMA(2,1,2)x(2,0,2,24) [intercept=True]; AIC=3137.258, BIC=3183.036, Time=63.150 seconds
# Fit ARIMA(2,1,2)x(1,0,2,24) [intercept=True]; AIC=3153.515, BIC=3194.716, Time=53.490 seconds
# Fit ARIMA(1,1,2)x(2,0,1,24) [intercept=True]; AIC=3057.875, BIC=3094.498, Time=112.795 seconds
# Fit ARIMA(2,1,1)x(2,0,1,24) [intercept=True]; AIC=3073.930, BIC=3110.553, Time=96.720 seconds
# Fit ARIMA(3,1,2)x(2,0,1,24) [intercept=True]; AIC=3053.761, BIC=3099.539, Time=102.007 seconds
# Fit ARIMA(2,1,3)x(2,0,1,24) [intercept=True]; AIC=3028.350, BIC=3074.129, Time=112.119 seconds
# Fit ARIMA(1,1,1)x(2,0,1,24) [intercept=True]; AIC=3076.755, BIC=3108.800, Time=58.681 seconds
# Fit ARIMA(1,1,3)x(2,0,1,24) [intercept=True]; AIC=3073.889, BIC=3115.090, Time=63.992 seconds
# Fit ARIMA(3,1,1)x(2,0,1,24) [intercept=True]; AIC=3056.203, BIC=3097.403, Time=93.937 seconds
# Fit ARIMA(3,1,3)x(2,0,1,24) [intercept=True]; AIC=3355.289, BIC=3405.645, Time=72.320 seconds
# Total fit time: 1193.208 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(2, 1, 2), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(2, 0, 1, 24),
#       start_params=None, suppress_warnings=True, trend='t',
#       with_intercept=True)

# %%
mod =  (train,
                                order=(2, 1, 2),
                                seasonal_order=(2, 0, 1, 24))

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2940      0.056     -5.276      0.000      -0.403      -0.185
# ar.L2          0.6057      0.042     14.587      0.000       0.524       0.687
# ma.L1         -0.0396      0.110     -0.359      0.720      -0.256       0.177
# ma.L2         -0.9601      0.034    -27.974      0.000      -1.027      -0.893
# ar.S.L24       1.0471      0.040     26.022      0.000       0.968       1.126
# ar.S.L48      -0.0543      0.039     -1.403      0.161      -0.130       0.022
# ma.S.L24      -0.8704      0.033    -26.169      0.000      -0.936      -0.805
# sigma2         3.1610      0.228     13.893      0.000       2.715       3.607
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
predict=results.get_prediction()
predict.predicted_mean[:900]
# Out:
# 0       0.000000
# 1      13.175984
# 2      15.065509
# 3      18.365565
# 4      18.209583
# 5      18.383734
# 6      19.021025
# 7      19.644417
# 8      20.811954
# 9      24.046470
# 10     20.707066
# 11     20.824885
# 12     21.139951
# 13     22.179893
# 14     23.084962
# 15     23.931254
# 16     25.875887
# 17     26.105770
# 18     26.939972
# 19     21.484432
# 20     19.593448
# 21     16.358930
# 22     15.801283
# 23     14.813411
# 24     14.644843
# 25     15.849887
# 26     17.823372
# 27     17.144067
# 28     19.207093
# 29     20.946620
#          ...
# 690    21.918536
# 691    18.471328
# 692    14.992104
# 693    12.260800
# 694    12.440085
# 695    12.106508
# 696    11.780685
# 697    13.229449
# 698    17.042614
# 699    15.069671
# 700    16.482960
# 701    16.280931
# 702    17.101481
# 703    19.314444
# 704    18.437335
# 705    19.015394
# 706    17.662382
# 707    18.261226
# 708    18.556558
# 709    17.740195
# 710    19.508132
# 711    21.137082
# 712    23.960384
# 713    25.544895
# 714    17.817301
# 715    15.832626
# 716    14.276663
# 717    13.663021
# 718    13.220192
# 719    12.401844
# Length: 720, dtype: float64

# %%
ax = df.y.plot(figsize=(25,6), color='black', title="Прогноз методом SARIMA" )
results.fittedvalues.plot(ax=ax, style='--', color='red')
predict.predicted_mean.plot(ax=ax, style='--', color='green')
plt.show()

# %%
metrics(test, predict.predicted_mean)
# Out:
# Тест на стационарность:
# 	T-статистика = -6.403
# 	P-значение = 0.000
# Критические значения :
# 	1%: -3.439620010600208 - Данные  стационарны с вероятностью 99% процентов
# 	5%: -2.8656309041017756 - Данные  стационарны с вероятностью 95% процентов
# 	10%: -2.5689484851894413 - Данные  стационарны с вероятностью 90% процентов
# MAD: 1.4277
# MSE: 3.6216
# MAPE: 0.0763
# MPE: -0.0166
# Стандартная ошибка: 1.903

# %%
#Монте-Карло
size = 720

# %%
df['y'].hist()

# %%
df[['y']].describe()
# Out:
#                 y
# count  720.000000
# mean    18.694600
# std      4.498866
# min     10.728000
# 25%     15.480000
# 50%     18.372000
# 75%     21.300000
# max     36.024000

# %%
consumpt = np.random.triangular(left = 10, mode = 18, right = 36, size = size)
plt.hist(consumpt)
# Out:
# (array([ 37.,  64., 121., 134., 113.,  88.,  83.,  42.,  28.,  10.]),
#  array([10.59197912, 13.10398901, 15.61599891, 18.1280088 , 20.6400187 ,
#         23.15202859, 25.66403849, 28.17604838, 30.68805827, 33.20006817,
#         35.71207806]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(consumpt)
